# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
os.getcwd() # Current Working directory
# Out:
# '/content'

# %%
# Create Working Directory if necessary

NoteBooks_ROOT_DIR = "/content/drive/MyDrive/Colab Notebooks/"

os.makedirs(NoteBooks_ROOT_DIR, exist_ok=True)

# %%
# Create Main Courses Directory and set as Working Directory

PROJECT_DIR = "/content/drive/MyDrive/Colab Notebooks/Cours MAE"

os.makedirs(PROJECT_DIR, exist_ok=True)

# Change the current working directory

os.chdir(PROJECT_DIR)
os.getcwd() # Current Working directory
# Out:
# '/content/drive/MyDrive/Colab Notebooks/Cours MAE'

# %%
# Create Sub Directories

path = "./models/"
os.makedirs(path, exist_ok=True)

path = "./data/"
os.makedirs(path, exist_ok=True)

path = "./images/"
os.makedirs(path, exist_ok=True)

path = "./library/"
os.makedirs(path, exist_ok=True)
